# %% [markdown]
# <a href="https://colab.research.google.com/github/CHENOOO45/kuo/blob/master/10_14_%E5%9B%9E%E5%AE%B6%E4%BD%9C%E6%A5%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
global a,b
a = input()
a = int(a)
b=a%4
print("輸入的年份是",a)
if b == 0:
  c = a%100
  if c == 0:
    d = a%400
    print("該年是閏年")
  else:
    print("該年不是閏年") 
else:
  print("該年不是閏年")
# Out:
# 2020
# 輸入的年份是 2020
# 該年不是閏年
